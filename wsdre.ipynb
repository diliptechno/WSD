# %%
import sys
import re
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from random import random
import numpy as np
import pandas as pd
import csv
from xml.dom import minidom
import xml.etree.ElementTree as et
import os
from nltk.stem import WordNetLemmatizer
import nltk

# %%
train = open("line-train.XML", "r")

# %%
sense = []
for line in train:
    sense.append(line)

# %%
sense
# Out:
# ['<corpus lang="en">\n',
#  '<lexelt item="line-n">\n',
#  '<instance id="line-n.w9_10:6830:">\n',
#  '<answer instance="line-n.w9_10:6830:" senseid="phone"/>\n',
#  '<context>\n',
#  "<s>The New York plan froze basic rates, offered no protection to Nynex against an economic downturn that sharply cut demand and didn't offer flexible pricing.</s><s>In contrast, the California economy is booming, with 4.5% access <head>line</head> growth in the past year.</s>\n",
#  '</context>\n',
#  '</instance>\n',
#  '<instance id="line-n.w8_057:16550:">\n',
#  '<answer instance="line-n.w8_057:16550:" senseid="product"/>\n',
#  '<context>\n',
#  '<s>According to analysts, sales of PS/2 got off to a rocky start but have risen lately -- especially in Europe.</s><s>IBM wants to establish the <head>line</head> as the new standard in personal computing in Europe.</s><s>It introduced the line in April 1987 and has said it shipped nearly two million units by its first anniversary.</s>\n',
# ...

# %%
str1 = ''.join(sense).lower()
sense1 = []
pattern = re.compile(r'senseid="(.*)"')
matches = pattern.finditer(str1)
for match in matches:
    sense1.append(match.group(1))

# %%
str1
# Out:
# '<corpus lang="en">\n<lexelt item="line-n">\n<instance id="line-n.w9_10:6830:">\n<answer instance="line-n.w9_10:6830:" senseid="phone"/>\n<context>\n<s>the new york plan froze basic rates, offered no protection to nynex against an economic downturn that sharply cut demand and didn\'t offer flexible pricing.</s><s>in contrast, the california economy is booming, with 4.5% access <head>line</head> growth in the past year.</s>\n</context>\n</instance>\n<instance id="line-n.w8_057:16550:">\n<answer instance="line-n.w8_057:16550:" senseid="product"/>\n<context>\n<s>according to analysts, sales of ps/2 got off to a rocky start but have risen lately -- especially in europe.</s><s>ibm wants to establish the <head>line</head> as the new standard in personal computing in europe.</s><s>it introduced the line in april 1987 and has said it shipped nearly two million units by its first anniversary.</s>\n</context>\n</instance>\n<instance id="line-n.w9_32:5971:">\n<answer instance="line-n.w9_32:5971
# ...

# %%
sense1
# Out:
# ['phone',
#  'product',
#  'product',
#  'phone',
#  'product',
#  'product',
#  'product',
#  'product',
#  'product',
#  'phone',
#  'product',
#  'phone',
#  'phone',
#  'phone',
#  'phone',
#  'phone',
#  'product',
#  'phone',
#  'product',
#  'product',
#  'phone',
#  'product',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'phone',
#  'phone',
#  'phone',
#  'product',
#  'phone',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'product',
#  'product',
#  'product',
#  'phone',
#  'phone',
#  'phone',
#  'phone',
#  'product',
#  'product',
#  'product',
#  'product',
#  'product',
#  'phone',
#  'product',
#  'phone',
#  'product',
#  'phone',
#  'product',
#  'phone',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'phone',
#  'phone',
#  'product',
#  'product',
#  'phone',
#  'phone',
#  'phone',
#  'product',
# ...

# %%
fdist_sense1 = FreqDist(sense1)
fdist_sense1
# Out:
# FreqDist({'phone': 178, 'product': 196})

# %%
sense2 = []
pattern1 = re.compile(r'<head>(.*)</head>')
matches1 = pattern1.finditer(str1)
for match1 in matches1:
    sense2.append(match1.group(1))

# %%
sense2
# Out:
# ['line',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
# ...

# %%
feat = []
pattern2 = re.compile(r'<head>(.*)</head>(.*)')
matches2 = pattern2.finditer(str1)
for match2 in matches2:
    feat.append(match2.group(2))

# %%
x = []
for line in feat:
    x.append(re.sub(r'(<s>|<\/s>)','',line))

# %%
x4 = []
lemmatizer = WordNetLemmatizer()
for line in x:
        y3 = lemmatizer.lemmatize(line)
        x4.append(y3)

# %%
x4
# Out:
# [' growth in the past year.',
#  ' as the new standard in personal computing in europe.it introduced the line in april 1987 and has said it shipped nearly two million units by its first anniversary.',
#  ' was scrapped.',
#  ' to current business customers by introducing them to various features of integrated services digital network, such as "inspect," which displays the name and telephone number of the party calling.',
#  ' and its first mainframe computer priced below $1 million.',
#  ' .',
#  " at more than $50 million last year.mr. jenko said the planned sale is part of a strategy to focus on the company's higher-margin lines, which include obsession perfume and cologne and other calvin klein fragrances.also, minnetonka said it signed an agreement in principle to market calvin klein industries inc.'s lines of women's small leather accessories world-wide under the calvin klein trademark.",
#  ' , is "a small part" of the shulton consumer products segment it acquired in 1971.',
# ...

# %%
x5 = []
tokenizer = RegexpTokenizer(r'\w+')
for line in x4:
        y4 = tokenizer.tokenize(line) 
        x5.append(y4)

# %%
# future for word after removing punctuation and using lemma
x5
# Out:
# [['growth', 'in', 'the', 'past', 'year'],
#  ['as',
#   'the',
#   'new',
#   'standard',
#   'in',
#   'personal',
#   'computing',
#   'in',
#   'europe',
#   'it',
#   'introduced',
#   'the',
#   'line',
#   'in',
#   'april',
#   '1987',
#   'and',
#   'has',
#   'said',
#   'it',
#   'shipped',
#   'nearly',
#   'two',
#   'million',
#   'units',
#   'by',
#   'its',
#   'first',
#   'anniversary'],
#  ['was', 'scrapped'],
#  ['to',
#   'current',
#   'business',
#   'customers',
#   'by',
#   'introducing',
#   'them',
#   'to',
#   'various',
#   'features',
#   'of',
#   'integrated',
#   'services',
#   'digital',
#   'network',
#   'such',
#   'as',
#   'inspect',
#   'which',
#   'displays',
#   'the',
#   'name',
#   'and',
#   'telephone',
#   'number',
#   'of',
#   'the',
#   'party',
#   'calling'],
#  ['and',
#   'its',
#   'first',
#   'mainframe',
#   'computer',
#   'priced',
#   'below',
#   '1',
#   'million'],
#  [],
#  ['at',
#   'more',
#   'than',
# ...

# %%
feat1 = []
pattern3 = re.compile(r'(.*)<head>(.*)</head>')
matches3 = pattern3.finditer(str1)
for match3 in matches3:
    feat1.append(match3.group(1))
feat1
#feat1 the part before the head -- list
# Out:
# ["<s>the new york plan froze basic rates, offered no protection to nynex against an economic downturn that sharply cut demand and didn't offer flexible pricing.</s><s>in contrast, the california economy is booming, with 4.5% access ",
#  '<s>according to analysts, sales of ps/2 got off to a rocky start but have risen lately -- especially in europe.</s><s>ibm wants to establish the ',
#  "<s>culinova fresh entrees, launched in 1986 by philip morris cos.'s general foods corp., hit similar distribution problems.</s><s>last december, shortly after philip morris bought kraft inc., the struggling ",
#  '<s>so far, the technique is working.</s><s>since january, southwestern bell has sold about 16,000 new ',
#  '<s>international business machines corp., in another move to regain ground on competitors such as digital equipment corp., unveiled four new models in its most powerful mid-range computer ',
# ...

# %%
x1 = []
for line in feat1:
    x1.append(re.sub(r'(<s>|<\/s>)','',line))
#x1
#after removing the <s> from feat1

# %%
x3 = []
lemmatizer = WordNetLemmatizer()
for line in x1:
        y2 = lemmatizer.lemmatize(line)
        x3.append(y2)

# %%
x3
# Out:
# ["the new york plan froze basic rates, offered no protection to nynex against an economic downturn that sharply cut demand and didn't offer flexible pricing.in contrast, the california economy is booming, with 4.5% access ",
#  'according to analysts, sales of ps/2 got off to a rocky start but have risen lately -- especially in europe.ibm wants to establish the ',
#  "culinova fresh entrees, launched in 1986 by philip morris cos.'s general foods corp., hit similar distribution problems.last december, shortly after philip morris bought kraft inc., the struggling ",
#  'so far, the technique is working.since january, southwestern bell has sold about 16,000 new ',
#  'international business machines corp., in another move to regain ground on competitors such as digital equipment corp., unveiled four new models in its most powerful mid-range computer ',
# ...

# %%
x2 = []
tokenizer = RegexpTokenizer(r'\w+')
for line in x1:
        y1 = tokenizer.tokenize(line) 
        x2.append(y1)

# %%
# past for word after removing punctuation and using lemma
x2
# Out:
# [['the',
#   'new',
#   'york',
#   'plan',
#   'froze',
#   'basic',
#   'rates',
#   'offered',
#   'no',
#   'protection',
#   'to',
#   'nynex',
#   'against',
#   'an',
#   'economic',
#   'downturn',
#   'that',
#   'sharply',
#   'cut',
#   'demand',
#   'and',
#   'didn',
#   't',
#   'offer',
#   'flexible',
#   'pricing',
#   'in',
#   'contrast',
#   'the',
#   'california',
#   'economy',
#   'is',
#   'booming',
#   'with',
#   '4',
#   '5',
#   'access'],
#  ['according',
#   'to',
#   'analysts',
#   'sales',
#   'of',
#   'ps',
#   '2',
#   'got',
#   'off',
#   'to',
#   'a',
#   'rocky',
#   'start',
#   'but',
#   'have',
#   'risen',
#   'lately',
#   'especially',
#   'in',
#   'europe',
#   'ibm',
#   'wants',
#   'to',
#   'establish',
#   'the'],
#  ['culinova',
#   'fresh',
#   'entrees',
#   'launched',
#   'in',
#   '1986',
#   'by',
#   'philip',
#   'morris',
#   'cos',
#   's',
#   'general',
#   'foods',
#   'corp',
#   'hit',
#   'similar',
# ...

# %%
# for line in feat1:
#     pat = re.compile(r'(([^\s>]+) [\S]+ )$')
#     mat = pat.search(line)
#     x =mat.group(1)
#     print(x)
past2 = []
for line in x2:
    past2.append(line[-10:])

# %%
# type(past2[1])
past2
# past2 - words before the head in the context
# Out:
# [['contrast',
#   'the',
#   'california',
#   'economy',
#   'is',
#   'booming',
#   'with',
#   '4',
#   '5',
#   'access'],
#  ['risen',
#   'lately',
#   'especially',
#   'in',
#   'europe',
#   'ibm',
#   'wants',
#   'to',
#   'establish',
#   'the'],
#  ['december',
#   'shortly',
#   'after',
#   'philip',
#   'morris',
#   'bought',
#   'kraft',
#   'inc',
#   'the',
#   'struggling'],
#  ['since',
#   'january',
#   'southwestern',
#   'bell',
#   'has',
#   'sold',
#   'about',
#   '16',
#   '000',
#   'new'],
#  ['four',
#   'new',
#   'models',
#   'in',
#   'its',
#   'most',
#   'powerful',
#   'mid',
#   'range',
#   'computer'],
#  ['the', 'ps', '2', 'up', 'from', 'some', '20', 'for', 'the', 'previous'],
#  ['president',
#   'and',
#   'general',
#   'counsel',
#   'estimated',
#   'total',
#   'sales',
#   'for',
#   'the',
#   'three'],
#  ['said',
#   'the',
#   'business',
#   'which',
#   'includes',
#   'the',
#   'la',
#   'prairie',
#   'skin',
# ...

# %%
# str2 = ''.join(feat1)
# past2 = []
# pattern4 = re.compile(r'<\/s><s>([^<]*)')
# matches4 = pattern4.finditer(str2)
# for match4 in matches4:
#     past2.append(match4.group(1))
fut2 = []
for line in x5:
    fut2.append(line[:10])

# %%
fut2
# Out:
# [['growth', 'in', 'the', 'past', 'year'],
#  ['as',
#   'the',
#   'new',
#   'standard',
#   'in',
#   'personal',
#   'computing',
#   'in',
#   'europe',
#   'it'],
#  ['was', 'scrapped'],
#  ['to',
#   'current',
#   'business',
#   'customers',
#   'by',
#   'introducing',
#   'them',
#   'to',
#   'various',
#   'features'],
#  ['and',
#   'its',
#   'first',
#   'mainframe',
#   'computer',
#   'priced',
#   'below',
#   '1',
#   'million'],
#  [],
#  ['at',
#   'more',
#   'than',
#   '50',
#   'million',
#   'last',
#   'year',
#   'mr',
#   'jenko',
#   'said'],
#  ['is',
#   'a',
#   'small',
#   'part',
#   'of',
#   'the',
#   'shulton',
#   'consumer',
#   'products',
#   'segment'],
#  ['and', 'properties', 'should', 'it', 'gain', 'control'],
#  ['to', 'order', 'it'],
#  ['could',
#   'fetch',
#   'about',
#   '300',
#   'million',
#   'estimates',
#   'mr',
#   'ryan',
#   'of',
#   'merrill'],
#  ['have', 'been', 'a', 'big', 'money', 'maker'],
#  ['that',
#   'has',
# ...

# %%
combined = [x+y for x,y in zip(past2,fut2)]
combined
# Out:
# [['contrast',
#   'the',
#   'california',
#   'economy',
#   'is',
#   'booming',
#   'with',
#   '4',
#   '5',
#   'access',
#   'growth',
#   'in',
#   'the',
#   'past',
#   'year'],
#  ['risen',
#   'lately',
#   'especially',
#   'in',
#   'europe',
#   'ibm',
#   'wants',
#   'to',
#   'establish',
#   'the',
#   'as',
#   'the',
#   'new',
#   'standard',
#   'in',
#   'personal',
#   'computing',
#   'in',
#   'europe',
#   'it'],
#  ['december',
#   'shortly',
#   'after',
#   'philip',
#   'morris',
#   'bought',
#   'kraft',
#   'inc',
#   'the',
#   'struggling',
#   'was',
#   'scrapped'],
#  ['since',
#   'january',
#   'southwestern',
#   'bell',
#   'has',
#   'sold',
#   'about',
#   '16',
#   '000',
#   'new',
#   'to',
#   'current',
#   'business',
#   'customers',
#   'by',
#   'introducing',
#   'them',
#   'to',
#   'various',
#   'features'],
#  ['four',
#   'new',
#   'models',
#   'in',
#   'its',
#   'most',
#   'powerful',
#   'mid',
#   'range',
# ...

# %%
combined 
#combining prev and after
# Out:
# [['contrast',
#   'the',
#   'california',
#   'economy',
#   'is',
#   'booming',
#   'with',
#   '4',
#   '5',
#   'access',
#   'growth',
#   'in',
#   'the',
#   'past',
#   'year'],
#  ['risen',
#   'lately',
#   'especially',
#   'in',
#   'europe',
#   'ibm',
#   'wants',
#   'to',
#   'establish',
#   'the',
#   'as',
#   'the',
#   'new',
#   'standard',
#   'in',
#   'personal',
#   'computing',
#   'in',
#   'europe',
#   'it'],
#  ['december',
#   'shortly',
#   'after',
#   'philip',
#   'morris',
#   'bought',
#   'kraft',
#   'inc',
#   'the',
#   'struggling',
#   'was',
#   'scrapped'],
#  ['since',
#   'january',
#   'southwestern',
#   'bell',
#   'has',
#   'sold',
#   'about',
#   '16',
#   '000',
#   'new',
#   'to',
#   'current',
#   'business',
#   'customers',
#   'by',
#   'introducing',
#   'them',
#   'to',
#   'various',
#   'features'],
#  ['four',
#   'new',
#   'models',
#   'in',
#   'its',
#   'most',
#   'powerful',
#   'mid',
#   'range',
# ...

# %%
bof_phone = []
bof_product = []

for i in range(len(sense1)):
    if(sense1[i]=="phone"):
        bof_phone.append(combined[i])
    else:
        bof_product.append(combined[i])

# %%
bof_phone
# Out:
# [['contrast',
#   'the',
#   'california',
#   'economy',
#   'is',
#   'booming',
#   'with',
#   '4',
#   '5',
#   'access',
#   'growth',
#   'in',
#   'the',
#   'past',
#   'year'],
#  ['since',
#   'january',
#   'southwestern',
#   'bell',
#   'has',
#   'sold',
#   'about',
#   '16',
#   '000',
#   'new',
#   'to',
#   'current',
#   'business',
#   'customers',
#   'by',
#   'introducing',
#   'them',
#   'to',
#   'various',
#   'features'],
#  ['for',
#   '19',
#   '95',
#   'and',
#   '5',
#   'of',
#   'callers',
#   'stay',
#   'on',
#   'the',
#   'to',
#   'order',
#   'it'],
#  ['of',
#   'french',
#   'phones',
#   'as',
#   'in',
#   'the',
#   'u',
#   's',
#   'the',
#   'gab',
#   'have',
#   'been',
#   'a',
#   'big',
#   'money',
#   'maker'],
#  ['securities',
#   'regulators',
#   'are',
#   'investigating',
#   'a',
#   'new',
#   'jersey',
#   'based',
#   'telephone',
#   'tip',
#   'that',
#   'has',
#   'been',
#   'getting',
#   'attention',
# ...

# %%
temp =[]
for item in bof_phone:
    temp += item
bof_phone = temp

temp = []
for item in bof_product:
    temp += item
bof_product = temp
bof_phone
# Out:
# ['contrast',
#  'the',
#  'california',
#  'economy',
#  'is',
#  'booming',
#  'with',
#  '4',
#  '5',
#  'access',
#  'growth',
#  'in',
#  'the',
#  'past',
#  'year',
#  'since',
#  'january',
#  'southwestern',
#  'bell',
#  'has',
#  'sold',
#  'about',
#  '16',
#  '000',
#  'new',
#  'to',
#  'current',
#  'business',
#  'customers',
#  'by',
#  'introducing',
#  'them',
#  'to',
#  'various',
#  'features',
#  'for',
#  '19',
#  '95',
#  'and',
#  '5',
#  'of',
#  'callers',
#  'stay',
#  'on',
#  'the',
#  'to',
#  'order',
#  'it',
#  'of',
#  'french',
#  'phones',
#  'as',
#  'in',
#  'the',
#  'u',
#  's',
#  'the',
#  'gab',
#  'have',
#  'been',
#  'a',
#  'big',
#  'money',
#  'maker',
#  'securities',
#  'regulators',
#  'are',
#  'investigating',
#  'a',
#  'new',
#  'jersey',
#  'based',
#  'telephone',
#  'tip',
#  'that',
#  'has',
#  'been',
#  'getting',
#  'attention',
#  'for',
#  'its',
#  'blend',
#  'of',
#  'inside',
#  'by',
#  'defense',
#  'may',
# ...

# %%
#pos tagging for bof_phone and bof_prod


bof_phone_pos = nltk.pos_tag(bof_phone)
bof_prod_pos = nltk.pos_tag(bof_product)

############################
bof_phone_tags = []
for w in bof_phone_pos:
    bof_phone_tags.append(w[1])
    

bof_prod_tags = []
for w in bof_prod_pos:
    bof_prod_tags.append(w[1])

# %%
bof_prod_tags
# Out:
# ['VB',
#  'RB',
#  'RB',
#  'IN',
#  'JJ',
#  'NN',
#  'VBZ',
#  'TO',
#  'VB',
#  'DT',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  'IN',
#  'JJ',
#  'NN',
#  'IN',
#  'NN',
#  'PRP',
#  'VBZ',
#  'RB',
#  'IN',
#  'NN',
#  'NN',
#  'VBD',
#  'NN',
#  'NN',
#  'DT',
#  'NN',
#  'VBD',
#  'VBN',
#  'CD',
#  'JJ',
#  'NNS',
#  'IN',
#  'PRP$',
#  'RBS',
#  'JJ',
#  'NN',
#  'NN',
#  'NN',
#  'CC',
#  'PRP$',
#  'JJ',
#  'NN',
#  'NN',
#  'VBN',
#  'IN',
#  'CD',
#  'CD',
#  'DT',
#  'NN',
#  'CD',
#  'IN',
#  'IN',
#  'DT',
#  'CD',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  'CC',
#  'JJ',
#  'NN',
#  'VBD',
#  'JJ',
#  'NNS',
#  'IN',
#  'DT',
#  'CD',
#  'IN',
#  'JJR',
#  'IN',
#  'CD',
#  'CD',
#  'JJ',
#  'NN',
#  'NN',
#  'NN',
#  'VBD',
#  'VBD',
#  'DT',
#  'NN',
#  'WDT',
#  'VBZ',
#  'DT',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  'VBZ',
#  'DT',
#  'JJ',
#  'NN',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  'NNS',
#  'NN',
#  'DT',
#  'JJ',
#  'NNS',
#  'VBD',
#  'PRP',
#  'MD',
#  'VB',
# ...

# %%
fdist_phone = FreqDist(bof_phone)
fdist_product = FreqDist(bof_product)
fdist_phone
# Out:
# FreqDist({'contrast': 2,
#           'the': 194,
#           'california': 1,
#           'economy': 1,
#           'is': 13,
#           'booming': 1,
#           'with': 16,
#           '4': 5,
#           '5': 8,
#           'access': 15,
#           'growth': 6,
#           'in': 45,
#           'past': 3,
#           'year': 9,
#           'since': 5,
#           'january': 1,
#           'southwestern': 2,
#           'bell': 5,
#           'has': 16,
#           'sold': 1,
#           'about': 10,
#           '16': 1,
#           '000': 12,
#           'new': 22,
#           'to': 83,
#           'current': 1,
#           'business': 7,
#           'customers': 7,
#           'by': 18,
#           'introducing': 1,
#           'them': 4,
#           'various': 1,
#           'features': 1,
#           'for': 36,
#           '19': 1,
#           '95': 2,
#           'and': 71,
#           'of': 62,
#           'callers': 4,
#           'stay': 1,
#           'on': 42,
# ...

# %%
#freq of total words
total = bof_phone + bof_product
fdist_total = FreqDist(total)
fdist_total
# Out:
# FreqDist({'contrast': 2,
#           'the': 347,
#           'california': 1,
#           'economy': 1,
#           'is': 36,
#           'booming': 1,
#           'with': 42,
#           '4': 10,
#           '5': 13,
#           'access': 15,
#           'growth': 10,
#           'in': 99,
#           'past': 4,
#           'year': 20,
#           'since': 7,
#           'january': 1,
#           'southwestern': 2,
#           'bell': 5,
#           'has': 29,
#           'sold': 4,
#           'about': 17,
#           '16': 1,
#           '000': 14,
#           'new': 50,
#           'to': 161,
#           'current': 8,
#           'business': 18,
#           'customers': 10,
#           'by': 35,
#           'introducing': 2,
#           'them': 6,
#           'various': 1,
#           'features': 1,
#           'for': 85,
#           '19': 1,
#           '95': 2,
#           'and': 156,
#           'of': 191,
#           'callers': 4,
#           'stay': 2,
#           'on': 60,
# ...

# %%
#########################




#testing





##########################

# %%
test = open("line-test.XML", "r")
test
# Out:
# <_io.TextIOWrapper name='line-test.XML' mode='r' encoding='UTF-8'>

# %%
t_sense = []
for line in test:
    t_sense.append(line)

# %%
t_sense
# Out:
# ['<corpus lang="en">\n',
#  '<lexelt item="line-n">\n',
#  '<instance id="line-n.w8_059:8174:">\n',
#  '<context>\n',
#  '<s>Advanced Micro Devices Inc., Sunnyvale, Calif., and Siemens AG of West Germany said they agreed to jointly develop, manufacture and market microchips for data communications and telecommunications with an emphasis on the integrated services digital network.</s><s>The integrated services digital network, or ISDN, is an international standard used to transmit voice, data, graphics and video images over telephone <head>lines</head> .</s>\n',
#  '</context>\n',
#  '</instance>\n',
#  '<instance id="line-n.w7_098:12684:">\n',
#  '<context>\n',
# ...

# %%
str2 = ''.join(t_sense).lower()
t_sense1 = []
pattern = re.compile(r'instance id="(.*)"')
matches = pattern.finditer(str2)
for match in matches:
    t_sense1.append(match.group(1))

# %%
len(t_sense1)
# Out:
# 126

# %%
t_sense2 = []
pattern = re.compile(r'<head>(.*)</head>')
matches = pattern.finditer(str2)
for match in matches:
    t_sense2.append(match.group(1))

# %%
t_sense2
# Out:
# ['lines',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'lines',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'lines',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'line',
#  'line',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'lines',
#  'line',
#  'lines',
# ...

# %%
t_feat = []
pattern = re.compile(r'<head>(.*)</head>(.*)')
matches = pattern.finditer(str2)
for match in matches:
    t_feat.append(match.group(2))

# %%
t_feat
# Out:
# [' .</s>',
#  ' open waiting for a connection uses communications switching and transmission equipment just as if a conversation were taking place.</s>',
#  " , are eating into federal's overnight business.</s>",
#  " and of children's horror-story and santa claus lines.</s><s>but movie marketers hope they can use the lines to entice potential moviegoers, especially teen-agers and young adults.</s>",
#  ' .</s>',
#  ' as part of its drive to "get back to basics" and focus on japanese cooking, joel schwartz, president, said in an interview.</s>',
#  " , running up an even bigger phone bill, the same voice goes on to advertise the movie, and would have gone on but i'd heard enough.</s>",
#  ' .</s>',
#  ' .</s>',
#  ' , for example, includes velvets and flowers worn close to the head.</s>',
#  " -- that's especially important now that there are an estimated 12 million home computers in america, apart from the millions of office systems.</s>",
# ...

# %%
x = []
for line in t_feat:
    x.append(re.sub(r'(<s>|<\/s>)','',line))

# %%
x
# Out:
# [' .',
#  ' open waiting for a connection uses communications switching and transmission equipment just as if a conversation were taking place.',
#  " , are eating into federal's overnight business.",
#  " and of children's horror-story and santa claus lines.but movie marketers hope they can use the lines to entice potential moviegoers, especially teen-agers and young adults.",
#  ' .',
#  ' as part of its drive to "get back to basics" and focus on japanese cooking, joel schwartz, president, said in an interview.',
#  " , running up an even bigger phone bill, the same voice goes on to advertise the movie, and would have gone on but i'd heard enough.",
#  ' .',
#  ' .',
#  ' , for example, includes velvets and flowers worn close to the head.',
#  " -- that's especially important now that there are an estimated 12 million home computers in america, apart from the millions of office systems.",
# ...

# %%
te1 = []
for line in x:
    te0 = lemmatizer.lemmatize(line)
    te1.append(te0)

# %%
te1
# Out:
# [' .',
#  ' open waiting for a connection uses communications switching and transmission equipment just as if a conversation were taking place.',
#  " , are eating into federal's overnight business.",
#  " and of children's horror-story and santa claus lines.but movie marketers hope they can use the lines to entice potential moviegoers, especially teen-agers and young adults.",
#  ' .',
#  ' as part of its drive to "get back to basics" and focus on japanese cooking, joel schwartz, president, said in an interview.',
#  " , running up an even bigger phone bill, the same voice goes on to advertise the movie, and would have gone on but i'd heard enough.",
#  ' .',
#  ' .',
#  ' , for example, includes velvets and flowers worn close to the head.',
#  " -- that's especially important now that there are an estimated 12 million home computers in america, apart from the millions of office systems.",
# ...

# %%
te2 = []
for line in te1:
        te_1 = tokenizer.tokenize(line) 
        te2.append(te_1)

# %%
te2
# Out:
# [[],
#  ['open',
#   'waiting',
#   'for',
#   'a',
#   'connection',
#   'uses',
#   'communications',
#   'switching',
#   'and',
#   'transmission',
#   'equipment',
#   'just',
#   'as',
#   'if',
#   'a',
#   'conversation',
#   'were',
#   'taking',
#   'place'],
#  ['are', 'eating', 'into', 'federal', 's', 'overnight', 'business'],
#  ['and',
#   'of',
#   'children',
#   's',
#   'horror',
#   'story',
#   'and',
#   'santa',
#   'claus',
#   'lines',
#   'but',
#   'movie',
#   'marketers',
#   'hope',
#   'they',
#   'can',
#   'use',
#   'the',
#   'lines',
#   'to',
#   'entice',
#   'potential',
#   'moviegoers',
#   'especially',
#   'teen',
#   'agers',
#   'and',
#   'young',
#   'adults'],
#  [],
#  ['as',
#   'part',
#   'of',
#   'its',
#   'drive',
#   'to',
#   'get',
#   'back',
#   'to',
#   'basics',
#   'and',
#   'focus',
#   'on',
#   'japanese',
#   'cooking',
#   'joel',
#   'schwartz',
#   'president',
#   'said',
#   'in',
#   'an',
#   'interview'],
# ...

# %%
t_feat1 = []
pattern = re.compile(r'(.*)<head>(.*)</head>')
matches = pattern.finditer(str2)
for match in matches:
    t_feat1.append(match.group(1))
t_feat1
# Out:
# ['<s>advanced micro devices inc., sunnyvale, calif., and siemens ag of west germany said they agreed to jointly develop, manufacture and market microchips for data communications and telecommunications with an emphasis on the integrated services digital network.</s><s>the integrated services digital network, or isdn, is an international standard used to transmit voice, data, graphics and video images over telephone ',
#  '<s>in your may 21 story about the phone industry billing customers for unconnected calls, i was surprised that you did not discuss whether such billing is appropriate.</s><s>a caller who keeps a ',
#  "<s>but he doesn't apologize for the idea, because zapmail was an effort to address a real and continuing problem.</s><s>facsimile machines, which transmit documents over telephone ",
# ...

# %%
x1 = []
for line in t_feat1:
    x1.append(re.sub(r'(<s>|<\/s>)','',line))
x1
# Out:
# ['advanced micro devices inc., sunnyvale, calif., and siemens ag of west germany said they agreed to jointly develop, manufacture and market microchips for data communications and telecommunications with an emphasis on the integrated services digital network.the integrated services digital network, or isdn, is an international standard used to transmit voice, data, graphics and video images over telephone ',
#  'in your may 21 story about the phone industry billing customers for unconnected calls, i was surprised that you did not discuss whether such billing is appropriate.a caller who keeps a ',
#  "but he doesn't apologize for the idea, because zapmail was an effort to address a real and continuing problem.facsimile machines, which transmit documents over telephone ",
# ...

# %%
te1_1 = []
for line in x1:
    te0_0 = lemmatizer.lemmatize(line)
    te1_1.append(te0_0)

# %%
te1_1
# Out:
# ['advanced micro devices inc., sunnyvale, calif., and siemens ag of west germany said they agreed to jointly develop, manufacture and market microchips for data communications and telecommunications with an emphasis on the integrated services digital network.the integrated services digital network, or isdn, is an international standard used to transmit voice, data, graphics and video images over telephone ',
#  'in your may 21 story about the phone industry billing customers for unconnected calls, i was surprised that you did not discuss whether such billing is appropriate.a caller who keeps a ',
#  "but he doesn't apologize for the idea, because zapmail was an effort to address a real and continuing problem.facsimile machines, which transmit documents over telephone ",
# ...

# %%
te2_2 = []
for line in te1_1:
        te_1_1 = tokenizer.tokenize(line) 
        te2_2.append(te_1_1)

# %%
te2_2
# Out:
# [['advanced',
#   'micro',
#   'devices',
#   'inc',
#   'sunnyvale',
#   'calif',
#   'and',
#   'siemens',
#   'ag',
#   'of',
#   'west',
#   'germany',
#   'said',
#   'they',
#   'agreed',
#   'to',
#   'jointly',
#   'develop',
#   'manufacture',
#   'and',
#   'market',
#   'microchips',
#   'for',
#   'data',
#   'communications',
#   'and',
#   'telecommunications',
#   'with',
#   'an',
#   'emphasis',
#   'on',
#   'the',
#   'integrated',
#   'services',
#   'digital',
#   'network',
#   'the',
#   'integrated',
#   'services',
#   'digital',
#   'network',
#   'or',
#   'isdn',
#   'is',
#   'an',
#   'international',
#   'standard',
#   'used',
#   'to',
#   'transmit',
#   'voice',
#   'data',
#   'graphics',
#   'and',
#   'video',
#   'images',
#   'over',
#   'telephone'],
#  ['in',
#   'your',
#   'may',
#   '21',
#   'story',
#   'about',
#   'the',
#   'phone',
#   'industry',
#   'billing',
#   'customers',
#   'for',
#   'unconnected',
#   'calls',
#   'i',
# ...

# %%
t_past2 = []
for line in te2_2:
    t_past2.append(line[-10:])

# %%
t_past2
# Out:
# [['to',
#   'transmit',
#   'voice',
#   'data',
#   'graphics',
#   'and',
#   'video',
#   'images',
#   'over',
#   'telephone'],
#  ['whether',
#   'such',
#   'billing',
#   'is',
#   'appropriate',
#   'a',
#   'caller',
#   'who',
#   'keeps',
#   'a'],
#  ['and',
#   'continuing',
#   'problem',
#   'facsimile',
#   'machines',
#   'which',
#   'transmit',
#   'documents',
#   'over',
#   'telephone'],
#  ['toll',
#   'telephone',
#   'services',
#   'have',
#   'mostly',
#   'been',
#   'the',
#   'stuff',
#   'of',
#   'pornography'],
#  ['flashing',
#   'lights',
#   'but',
#   'a',
#   'poor',
#   'record',
#   'of',
#   'finding',
#   'a',
#   'free'],
#  ['plans',
#   'to',
#   'close',
#   'its',
#   'unprofitable',
#   'big',
#   'splash',
#   'seafood',
#   'emporium',
#   'restaurant'],
#  ['a',
#   'plug',
#   'for',
#   'continental',
#   'airlines',
#   'if',
#   'you',
#   'stay',
#   'on',
#   'the'],
#  ['shopping',
#   'and',
#   'retrieving',
# ...

# %%
t_fut2 = []
for line in te2:
    t_fut2.append(line[:10])

# %%
t_fut2
# Out:
# [[],
#  ['open',
#   'waiting',
#   'for',
#   'a',
#   'connection',
#   'uses',
#   'communications',
#   'switching',
#   'and',
#   'transmission'],
#  ['are', 'eating', 'into', 'federal', 's', 'overnight', 'business'],
#  ['and',
#   'of',
#   'children',
#   's',
#   'horror',
#   'story',
#   'and',
#   'santa',
#   'claus',
#   'lines'],
#  [],
#  ['as', 'part', 'of', 'its', 'drive', 'to', 'get', 'back', 'to', 'basics'],
#  ['running',
#   'up',
#   'an',
#   'even',
#   'bigger',
#   'phone',
#   'bill',
#   'the',
#   'same',
#   'voice'],
#  [],
#  [],
#  ['for',
#   'example',
#   'includes',
#   'velvets',
#   'and',
#   'flowers',
#   'worn',
#   'close',
#   'to',
#   'the'],
#  ['that',
#   's',
#   'especially',
#   'important',
#   'now',
#   'that',
#   'there',
#   'are',
#   'an',
#   'estimated'],
#  ['are',
#   'jammed',
#   'when',
#   'stock',
#   'prices',
#   'made',
#   'sharp',
#   'corrections',
#   'earlier',
#   'this'],
#  ['to',
#   'the',
# ...

# %%
t_combined = [x+y for x,y in zip(t_past2,t_fut2)]
t_combined
# Out:
# [['to',
#   'transmit',
#   'voice',
#   'data',
#   'graphics',
#   'and',
#   'video',
#   'images',
#   'over',
#   'telephone'],
#  ['whether',
#   'such',
#   'billing',
#   'is',
#   'appropriate',
#   'a',
#   'caller',
#   'who',
#   'keeps',
#   'a',
#   'open',
#   'waiting',
#   'for',
#   'a',
#   'connection',
#   'uses',
#   'communications',
#   'switching',
#   'and',
#   'transmission'],
#  ['and',
#   'continuing',
#   'problem',
#   'facsimile',
#   'machines',
#   'which',
#   'transmit',
#   'documents',
#   'over',
#   'telephone',
#   'are',
#   'eating',
#   'into',
#   'federal',
#   's',
#   'overnight',
#   'business'],
#  ['toll',
#   'telephone',
#   'services',
#   'have',
#   'mostly',
#   'been',
#   'the',
#   'stuff',
#   'of',
#   'pornography',
#   'and',
#   'of',
#   'children',
#   's',
#   'horror',
#   'story',
#   'and',
#   'santa',
#   'claus',
#   'lines'],
#  ['flashing',
#   'lights',
#   'but',
#   'a',
#   'poor',
#   'record',
# ...

# %%
total
# Out:
# ['contrast',
#  'the',
#  'california',
#  'economy',
#  'is',
#  'booming',
#  'with',
#  '4',
#  '5',
#  'access',
#  'growth',
#  'in',
#  'the',
#  'past',
#  'year',
#  'since',
#  'january',
#  'southwestern',
#  'bell',
#  'has',
#  'sold',
#  'about',
#  '16',
#  '000',
#  'new',
#  'to',
#  'current',
#  'business',
#  'customers',
#  'by',
#  'introducing',
#  'them',
#  'to',
#  'various',
#  'features',
#  'for',
#  '19',
#  '95',
#  'and',
#  '5',
#  'of',
#  'callers',
#  'stay',
#  'on',
#  'the',
#  'to',
#  'order',
#  'it',
#  'of',
#  'french',
#  'phones',
#  'as',
#  'in',
#  'the',
#  'u',
#  's',
#  'the',
#  'gab',
#  'have',
#  'been',
#  'a',
#  'big',
#  'money',
#  'maker',
#  'securities',
#  'regulators',
#  'are',
#  'investigating',
#  'a',
#  'new',
#  'jersey',
#  'based',
#  'telephone',
#  'tip',
#  'that',
#  'has',
#  'been',
#  'getting',
#  'attention',
#  'for',
#  'its',
#  'blend',
#  'of',
#  'inside',
#  'by',
#  'defense',
#  'may',
# ...

# %%
total_pos_tag[0]
# Out:
# ('contrast', 'NN')

# %%
#######################################

total_pos_tag = nltk.pos_tag(total)
total_tags = []
for w in total_pos_tag:
    total_tags.append(w[1])
    


#######################################

# %%
total_tags
# Out:
# ['NN',
#  'DT',
#  'NN',
#  'NN',
#  'VBZ',
#  'VBG',
#  'IN',
#  'CD',
#  'CD',
#  'NN',
#  'NN',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  'IN',
#  'JJ',
#  'NN',
#  'NN',
#  'VBZ',
#  'VBN',
#  'IN',
#  'CD',
#  'CD',
#  'JJ',
#  'TO',
#  'JJ',
#  'NN',
#  'NNS',
#  'IN',
#  'VBG',
#  'PRP',
#  'TO',
#  'JJ',
#  'NNS',
#  'IN',
#  'CD',
#  'CD',
#  'CC',
#  'CD',
#  'IN',
#  'NNS',
#  'VBP',
#  'IN',
#  'DT',
#  'TO',
#  'NN',
#  'PRP',
#  'IN',
#  'JJ',
#  'NNS',
#  'IN',
#  'IN',
#  'DT',
#  'JJ',
#  'VBZ',
#  'DT',
#  'NN',
#  'VBP',
#  'VBN',
#  'DT',
#  'JJ',
#  'NN',
#  'NN',
#  'NNS',
#  'NNS',
#  'VBP',
#  'VBG',
#  'DT',
#  'JJ',
#  'NN',
#  'VBN',
#  'NN',
#  'NN',
#  'WDT',
#  'VBZ',
#  'VBN',
#  'VBG',
#  'NN',
#  'IN',
#  'PRP$',
#  'NN',
#  'IN',
#  'NN',
#  'IN',
#  'NN',
#  'MD',
#  'VB',
#  'CD',
#  'VBN',
#  'CC',
#  'DT',
#  'JJ',
#  'NN',
#  'TO',
#  'PRP',
#  'VB',
#  'JJ',
#  'NN',
#  'RB',
#  'RB',
#  'TO',
#  'VB',
#  'DT',
#  'JJ',
#  'IN',
#  'DT',
#  'JJ',
# ...

# %%
#probabilities P(s)
output = []
temp = 0
for j in range(len(t_combined)):
    for i in range(len(t_combined[j])):
        #sense phone
        prob_phone = []
        if t_combined[j][i] in total:
            prob_word = fdist_phone[t_combined[j][i]]/fdist_total[t_combined[j][i]]
            prob_feature = fdist_phone[t_combined[j][i]]/fdist_sense1["phone"]
            prob_phone.append(prob_word * prob_feature)
        else:
            prob_phone.append(fdist_sense1["phone"]/len(sense1))
            temp+=1

        #sense product
        prob_product = []
        if t_combined[j][i] in total:
            prob_word = fdist_product[t_combined[j][i]]/fdist_total[t_combined[j][i]]
            prob_feature = fdist_product[t_combined[j][i]]/fdist_sense1["product"]
            prob_product.append(prob_word * prob_feature)
        else:
            prob_product.append(fdist_sense1["product"]/len(sense1))
            temp+=1
        
    final_phone = 1
    final_product = 1
    
    for item in prob_phone:
        final_phone = final_phone * item
    for item in prob_product:
        final_product = final_product * item
    
    if(final_phone>final_product):
        output.append("phone")
    else:
        output.append("product")

# %%
temp
# Out:
# 856

# %%
answers = open("line-answers.txt", "r")
answers2 = []
for line in answers:
    answers2.append(line)
answers2
# Out:
# ['<answer instance="line-n.w8_059:8174:" senseid="phone"/>\n',
#  '<answer instance="line-n.w7_098:12684:" senseid="phone"/>\n',
#  '<answer instance="line-n.w8_106:13309:" senseid="phone"/>\n',
#  '<answer instance="line-n.w9_40:10187:" senseid="phone"/>\n',
#  '<answer instance="line-n.w9_16:217:" senseid="phone"/>\n',
#  '<answer instance="line-n.w8_119:16927:" senseid="product"/>\n',
#  '<answer instance="line-n.w8_008:13756:" senseid="phone"/>\n',
#  '<answer instance="line-n.w8_041:15186:" senseid="phone"/>\n',
#  '<answer instance="line-n.art7} aphb 05601797:" senseid="phone"/>\n',
#  '<answer instance="line-n.w8_119:2964:" senseid="product"/>\n',
#  '<answer instance="line-n.w7_040:13652:" senseid="phone"/>\n',
#  '<answer instance="line-n.w7_122:2194:" senseid="phone"/>\n',
#  '<answer instance="line-n.art7} aphb 45903907:" senseid="phone"/>\n',
#  '<answer instance="line-n.art7} aphb 43602625:" senseid="phone"/>\n',
# ...

# %%
str3 = ''.join(answers2)
sense_ans = []
pattern = re.compile(r'senseid="(.*)"')
matches = pattern.finditer(str3)
for match in matches:
    sense_ans.append(match.group(1))

# %%
#accuracy

sum = 0
for i in range(len(output)):
    if(output[i]==sense_ans[i]):
        sum+=1
accuracy = sum/len(output)
accuracy
# Out:
# 0.6587301587301587

# %%
type(total_pos_tag)
# Out:
# list

# %%
#should convert to lower
